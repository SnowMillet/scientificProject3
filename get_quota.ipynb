# %%
import rqdatac

rqdatac.init()
rqdatac.user.get_quota()
# Out:
# ---------------------------------------------------------------------------
# QuotaExceeded                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18320/117092045.py in <module>
#       2
#       3 rqdatac.init()
# ----> 4 rqdatac.user.get_quota()
#
# c:\users\millet\miniconda3\envs\torch1.8-gpu\lib\site-packages\rqdatac\services\basic.py in get_quota()
#     834         license_type：账户类型(FULL: 付费类型，TRIAL: 试用类型， EDU: 教育网类型, OTHER: 其他类型)
#     835     """
# --> 836     data = get_client().execute("user.get_quota")
#     837     if data['bytes_limit'] > 0 and data["bytes_used"] >= data["bytes_limit"]:
#     838         warnings.warn("Traffic usage has been exceeded quota,"
#
# c:\users\millet\miniconda3\envs\torch1.8-gpu\lib\site-packages\rqdatac\decorators.py in wrap(*args, **kwargs)
#      65             while c > 0:
#      66                 try:
# ---> 67                     return func(*args, **kwargs)
# ...
